# %% [markdown]
# Add two strings.

# %%
# Problem

n = int(input())
result = []

for i in range(1, n+1) :
    result.append("결과" + i + ".txt");

for r in result :
    print(r)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-171a4a2c9237> in <module>()
#       5
#       6 for i in range(1, n+1) :
# ----> 7     result.append("결과" + i + ".txt");
#       8
#       9 for r in result :
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Solution 1

n = int(input())
result = []

for i in range(n):
    result.append("결과" + str(i+1) + ".txt")

for r in result:
    print(r)
# Out:
# 5
# 결과1.txt
# 결과2.txt
# 결과3.txt
# 결과4.txt
# 결과5.txt

# %%
# Solution 2

n = int(input())
result = []

for i in range(1, n+1):
    result.append("결과" + str(i) + ".txt")

for r in result:
    print(r)
# Out:
# 5
# 결과1.txt
# 결과2.txt
# 결과3.txt
# 결과4.txt
# 결과5.txt
